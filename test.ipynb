# %%
import heapq
heap = []
for x in [(5,2,2),(5,2,1), (1,3,1), (7,3,6),(7,4,1), (3,4,1)]:
    heapq.heappush(heap, x)
while heap:
    print(heapq.heappop(heap))
# Out:
# (1, 3, 1)
# (3, 4, 1)
# (5, 2, 1)
# (5, 2, 2)
# (7, 3, 1)
